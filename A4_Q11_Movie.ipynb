# %%
'''
Perform the following operations using Python on Movie data sets  
m. Create data subsets for different languages(Original Language).  
n. Merge two subsets  
o. Sort Data using customer ratings.  
p. Transposing Data  
q. Melting Data to long format  
r. Casting data to wide format  
'''
# Out:
# '\nPerform the following operations using Python on Movie data sets  \nm. Create data subsets for different languages(Original Language).  \nn. Merge two subsets  \no. Sort Data using customer ratings.  \np. Transposing Data  \nq. Melting Data to long format  \nr. Casting data to wide format  \n'

# %%
import pandas as pd

# %%
movies = pd.read_csv(r'DSBDALExam DataSets\Movie\movies_metadata.csv')
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_8736\2744998653.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv(r'DSBDALExam DataSets\Movie\movies_metadata.csv')

# %%
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
data.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
ratings = pd.read_csv(r'DSBDALExam DataSets\Movie\ratings_small.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
print(movies['original_language'].value_counts())
# Out:
# original_language
# en       32269
# fr        2438
# it        1529
# ja        1350
# de        1080
#          ...
# zu           1
# qu           1
# 104.0        1
# la           1
# si           1
# Name: count, Length: 92, dtype: int64

# %%
# Create data subsets for different languages(Original Language).  
english_movies = movies[movies['original_language'] == 'en']
french_movies = movies[movies['original_language'] == 'fr']
italian_movies = movies[movies['original_language'] == 'it']

# %%
# Merge two subsets
merged_movies = pd.concat([english_movies, french_movies], ignore_index=True)
print(merged_movies.head())
print(merged_movies.tail())
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# Sort Data using customer ratings
sorted_data = movies.sort_values(by='vote_average', ascending=False)
print(sorted_data.head())
# Out:
#        adult belongs_to_collection  budget  \
# 21642  False                   NaN       0
# 15710  False                   NaN       0
# 22396  False                   NaN       0
# 22395  False                   NaN       0
# 35343  False                   NaN  300000
#
#                                                   genres  \
# 21642                [{'id': 99, 'name': 'Documentary'}]
# 15710                [{'id': 99, 'name': 'Documentary'}]
# 22396                [{'id': 99, 'name': 'Documentary'}]
# 22395                [{'id': 99, 'name': 'Documentary'}]
# 35343  [{'id': 35, 'name': 'Comedy'}, {'id': 99, 'nam...
#
#                                   homepage      id    imdb_id  \
# 21642                                  NaN  320849  tt0886500
# 15710                                  NaN   96451  tt1587373
# 22396                                  NaN   72123  tt1341746
# 22395  http://www.marvinhamlischmovie.com/  230864  tt3011874
# ...

# %%
# Transposing Data
transposed_movies = movies.head().transpose()
print(transposed_movies.head())
# Out:
#                                                                        0  \
# adult                                                              False
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          30000000
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                            http://toystory.disney.com/toy-story
#
#                                                                        1  \
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                          65000000
# genres                 [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                                                             NaN
#
#                                                                        2  \
# ...

# %%
# Melting Data to long format
melted_movies = pd.melt(movies[['id', 'original_language', 'title']], id_vars=['id'], 
                        var_name='Attribute', value_name='Value')
print(melted_movies.head())
# Out:
#       id          Attribute Value
# 0    862  original_language    en
# 1   8844  original_language    en
# 2  15602  original_language    en
# 3  31357  original_language    en
# 4  11862  original_language    en

# %%
# Casting data back to wide format
wide_movies = melted_movies.pivot_table(index='id', 
                                        columns='Attribute', 
                                        values='Value', 
                                        aggfunc='first').reset_index()

print(wide_movies.head())
# Out:
# Attribute      id original_language                                title
# 0             100                en  Lock, Stock and Two Smoking Barrels
# 1           10000                es            La estrategia del caracol
# 2           10001                en                       Young Einstein
# 3          100010                en                       Flight Command
# 4          100017                de                              Hounded
